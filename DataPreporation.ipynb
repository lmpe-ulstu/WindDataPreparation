# %%
import pandas as pd
import math

# def normal(x):
#     if x == 0: return 0
#     return x/(math.pi*2)

rawData = pd.read_csv('data/data.scv', sep='\t')
rawData.time = pd.to_datetime(rawData.time)
rawData = rawData.set_index(rawData.time)
rawData = rawData.drop(['time'],axis=1)
#rawData = rawData.drop(['time','dispHeight','wSpeed.850hpa','temperature.50','wDir.850hpa','msl'],axis=1)
# rawData['wDir.50']=rawData['wDir.50'].apply(math.radians)
# rawData['wDir.50']=rawData['wDir.50'].apply(normal)
rawData.head()
# Out:
#                          psfc       msl  wSpeed.50  wDir.50  wSpeed.850hpa  \
# time
# 1990-01-01 00:00:00  100222.2  101272.5      11.27    259.6          18.02
# 1990-01-01 01:00:00  100068.3  101118.8      11.65    261.6          19.68
# 1990-01-01 02:00:00   99929.3  100975.7      12.53    267.1          20.97
# 1990-01-01 03:00:00   99843.4  100890.6      12.16    272.1          21.43
# 1990-01-01 04:00:00   99813.9  100869.8      11.81    279.3          20.91
#
#                      wDir.850hpa  temperature.10  temperature.50  dispHeight  \
# time
# 1990-01-01 00:00:00        293.3          -10.63          -11.43         0.1
# 1990-01-01 01:00:00        295.1           -9.37          -10.21         0.1
# 1990-01-01 02:00:00        300.0           -7.51           -8.43         0.1
# 1990-01-01 03:00:00        305.3           -6.51           -7.41         0.1
# 1990-01-01 04:00:00        310.8           -6.38           -7.23         0.1
#
#                      precIceWater  precLiqWater  precWaterVapor  \
# time
# 1990-01-01 00:00:00           0.0           1.3          6212.4
# 1990-01-01 01:00:00           0.0           0.3          6500.8
# 1990-01-01 02:00:00           0.0           0.0          5970.2
# 1990-01-01 03:00:00           0.1           0.0          5753.2
# 1990-01-01 04:00:00           0.9           6.1          6736.5
#
#                      specHumidity.10
# time
# 1990-01-01 00:00:00              1.4
# 1990-01-01 01:00:00              1.5
# 1990-01-01 02:00:00              1.7
# 1990-01-01 03:00:00              1.9
# 1990-01-01 04:00:00              1.9

# %%
import seaborn as sns

# %%
sns.set()
ax = sns.heatmap(rawData.corr(),annot=True,fmt='.1f')

# %%
rawData.plot()
# Out:
# <AxesSubplot: xlabel='time'>

# %%
rawData.isnull().sum()
# Out:
# psfc               0
# msl                0
# wSpeed.50          0
# wDir.50            0
# wSpeed.850hpa      0
# wDir.850hpa        0
# temperature.10     0
# temperature.50     0
# dispHeight         0
# precIceWater       0
# precLiqWater       0
# precWaterVapor     0
# specHumidity.10    0
# dtype: int64

# %%
rawData.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot: title={'center': 'psfc'}>,
#         <AxesSubplot: title={'center': 'msl'}>,
#         <AxesSubplot: title={'center': 'wSpeed.50'}>,
#         <AxesSubplot: title={'center': 'wDir.50'}>],
#        [<AxesSubplot: title={'center': 'wSpeed.850hpa'}>,
#         <AxesSubplot: title={'center': 'wDir.850hpa'}>,
#         <AxesSubplot: title={'center': 'temperature.10'}>,
#         <AxesSubplot: title={'center': 'temperature.50'}>],
#        [<AxesSubplot: title={'center': 'dispHeight'}>,
#         <AxesSubplot: title={'center': 'precIceWater'}>,
#         <AxesSubplot: title={'center': 'precLiqWater'}>,
#         <AxesSubplot: title={'center': 'precWaterVapor'}>],
#        [<AxesSubplot: title={'center': 'specHumidity.10'}>,
#         <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >]], dtype=object)

# %%
rawData.describe()
# Out:
#                 psfc            msl      wSpeed.50        wDir.50  \
# count  280512.000000  280512.000000  280512.000000  280512.000000
# mean   100622.152572  101655.338422       6.685010     200.542182
# std      1045.823625    1062.493350       2.806557      98.373658
# min     96126.400000   97138.700000       0.030000       0.000000
# 25%     99943.600000  100960.500000       4.710000     135.400000
# 50%    100567.500000  101590.300000       6.670000     212.900000
# 75%    101241.900000  102284.600000       8.480000     278.600000
# max    105146.800000  106263.800000      22.260000     360.000000
#
#        wSpeed.850hpa    wDir.850hpa  temperature.10  temperature.50  \
# count  280512.000000  280512.000000   280512.000000   280512.000000
# mean        9.394307     219.194254        4.688459        4.106794
# std         4.955147      95.886377       13.577917       13.748053
# min         0.010000       0.000000      -40.100000      -41.880000
# 25%         5.700000     170.575000       -5.590000       -6.270000
# 50%         8.740000     240.600000        4.920000        4.400000
# 75%        12.390000     291.600000       16.300000       15.820000
# max        40.560000     360.000000       39.040000       38.800000
#
#           dispHeight   precIceWater   precLiqWater  precWaterVapor  \
# count  280512.000000  280512.000000  280512.000000   280512.000000
# mean        0.131314      17.018473      56.068449    14304.466322
# std         0.077840      32.937532      71.341311     9248.444843
# min         0.000000       0.000000       0.000000      761.500000
# 25%         0.100000       0.200000       5.200000     6703.600000
# 50%         0.200000       2.400000      26.400000    11939.300000
# 75%         0.200000      17.600000      81.200000    20676.300000
# max         0.300000     516.100000     578.100000    47022.600000
#
#        specHumidity.10
# count    280512.000000
# mean          5.026387
# std           3.486317
# min           0.100000
# 25%           2.100000
# 50%           4.100000
# 75%           7.500000
# max          18.300000

# %%
from statsmodels.tsa.seasonal import STL

stl = STL(rawData['temperature.10'][:1000], seasonal=13)
res = stl.fit()

# %%
res.plot
# Out:
# <bound method DecomposeResult.plot of <statsmodels.tsa.seasonal.DecomposeResult object at 0x000002CA06F80A90>>

# %%
from sklearn import preprocessing
import numpy as np

scaler = preprocessing.MinMaxScaler().fit(X=np.array(rawData))
DataScaler = scaler.transform(np.array(rawData))

# %%
DataScaler
# Out:
# array([[4.54059687e-01, 4.53014214e-01, 5.05623032e-01, ...,
#         2.24874589e-03, 1.17829018e-01, 7.14285714e-02],
#        [4.36998359e-01, 4.36170563e-01, 5.22717049e-01, ...,
#         5.18941360e-04, 1.24063198e-01, 7.69230769e-02],
#        [4.21588843e-01, 4.20488543e-01, 5.62303194e-01, ...,
#         0.00000000e+00, 1.12593518e-01, 8.79120879e-02],
#        ...,
#        [4.41665558e-01, 4.43206102e-01, 2.93747188e-01, ...,
#         9.58311711e-02, 1.23029932e-01, 6.04395604e-02],
#        [4.38339763e-01, 4.39162311e-01, 3.05443095e-01, ...,
#         5.67375887e-02, 1.24285847e-01, 6.59340659e-02],
#        [4.32963062e-01, 4.33562372e-01, 3.10391363e-01, ...,
#         4.94724096e-02, 1.29387325e-01, 6.59340659e-02]])

# %%
df = pd.DataFrame(DataScaler, columns=rawData.columns)

# %%
df.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'psfc'}>,
#         <AxesSubplot: title={'center': 'msl'}>,
#         <AxesSubplot: title={'center': 'wSpeed.50'}>,
#         <AxesSubplot: title={'center': 'wDir.50'}>],
#        [<AxesSubplot: title={'center': 'wSpeed.850hpa'}>,
#         <AxesSubplot: title={'center': 'wDir.850hpa'}>,
#         <AxesSubplot: title={'center': 'temperature.10'}>,
#         <AxesSubplot: title={'center': 'temperature.50'}>],
#        [<AxesSubplot: title={'center': 'dispHeight'}>,
#         <AxesSubplot: title={'center': 'precIceWater'}>,
#         <AxesSubplot: title={'center': 'precLiqWater'}>,
#         <AxesSubplot: title={'center': 'precWaterVapor'}>],
#        [<AxesSubplot: title={'center': 'specHumidity.10'}>,
#         <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >]], dtype=object)

# %%
df.plot()
# Out:
# <AxesSubplot: >
