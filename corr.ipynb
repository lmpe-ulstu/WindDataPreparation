# %%
import pandas as pd
import math

# def normal(x):
#     if x == 0: return 0
#     return x/(math.pi*2)

rawData = pd.read_csv('data/data.scv', sep='\t')
rawData.time = pd.to_datetime(rawData.time)
rawData = rawData.set_index(rawData.time)
rawData = rawData.drop(['time'],axis=1)
#rawData = rawData.drop(['time','dispHeight','wSpeed.850hpa','temperature.50','wDir.850hpa','msl'],axis=1)
# rawData['wDir.50']=rawData['wDir.50'].apply(math.radians)
# rawData['wDir.50']=rawData['wDir.50'].apply(normal)
rawData['month'] = rawData.index.month
rawData['year'] = rawData.index.year%4
rawData['hour'] = rawData.index.hour

rawData.head()
# Out:
#                          psfc       msl  wSpeed.50  wDir.50  wSpeed.850hpa  \
# time
# 1990-01-01 00:00:00  100222.2  101272.5      11.27    259.6          18.02
# 1990-01-01 01:00:00  100068.3  101118.8      11.65    261.6          19.68
# 1990-01-01 02:00:00   99929.3  100975.7      12.53    267.1          20.97
# 1990-01-01 03:00:00   99843.4  100890.6      12.16    272.1          21.43
# 1990-01-01 04:00:00   99813.9  100869.8      11.81    279.3          20.91
#
#                      wDir.850hpa  temperature.10  temperature.50  dispHeight  \
# time
# 1990-01-01 00:00:00        293.3          -10.63          -11.43         0.1
# 1990-01-01 01:00:00        295.1           -9.37          -10.21         0.1
# 1990-01-01 02:00:00        300.0           -7.51           -8.43         0.1
# 1990-01-01 03:00:00        305.3           -6.51           -7.41         0.1
# 1990-01-01 04:00:00        310.8           -6.38           -7.23         0.1
#
# ...

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(15,6)})

# %% [markdown]
# Корреляция по всем данным

# %%
ax = sns.heatmap(rawData.corr(),annot=True,fmt='.1f')

# %% [markdown]
# Коррелляция по месяцам

# %%
ax= sns.heatmap(rawData[rawData.month == 1].corr(),annot=True,fmt='.1f')

# %%
ax= sns.heatmap(rawData[rawData.month == 2].corr(),annot=True,fmt='.1f')

# %%
ax= sns.heatmap(rawData[rawData.month == 3].corr(),annot=True,fmt='.1f')

# %%
ax= sns.heatmap(rawData[rawData.month == 4].corr(),annot=True,fmt='.1f')

# %%
ax= sns.heatmap(rawData[rawData.month == 5].corr(),annot=True,fmt='.1f')

# %%
ax= sns.heatmap(rawData[rawData.month == 6].corr(),annot=True,fmt='.1f')

# %%
ax= sns.heatmap(rawData[rawData.month == 7].corr(),annot=True,fmt='.1f')

# %%
ax= sns.heatmap(rawData[rawData.month == 8].corr(),annot=True,fmt='.1f')

# %%
ax= sns.heatmap(rawData[rawData.month == 9].corr(),annot=True,fmt='.1f')

# %%
ax= sns.heatmap(rawData[rawData.month == 10].corr(),annot=True,fmt='.1f')

# %%
ax= sns.heatmap(rawData[rawData.month == 11].corr(),annot=True,fmt='.1f')

# %%
ax= sns.heatmap(rawData[rawData.month == 12].corr(),annot=True,fmt='.1f')

# %% [markdown]
# Исследование корреляции по годам

# %%
ax= sns.heatmap(rawData[rawData.index.year == 1992].corr(),annot=True,fmt='.1f')

# %%
import random as rnd

ax= sns.heatmap(rawData[rawData.index.year == 2021].corr(),annot=True,fmt='.1f')

# %%
ax= sns.heatmap(rawData[rawData.index.year == 2005].corr(),annot=True,fmt='.1f')

# %% [markdown]
# Исследование по часам за сколько часов размываеться корреляция

# %%
i = 0

ax= sns.heatmap(rawData[i:i+6:].corr(),annot=True,fmt='.1f')

# %%
i = i+10000
ax= sns.heatmap(rawData[i:i+6:].corr(),annot=True,fmt='.1f')

# %%
i = i+10000
ax= sns.heatmap(rawData[i:i+6:].corr(),annot=True,fmt='.1f')

# %%
i = i+10000
ax= sns.heatmap(rawData[i:i+6:].corr(),annot=True,fmt='.1f')
